# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a simple dataset
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
sales = [15000, 18000, 22000, 21000, 26000, 30000]
profit = [3000, 4000, 5000, 4500, 6000, 7000]
customers = [120, 150, 180, 170, 200, 220]

# %% [markdown]
# # Line Chart

# %%
plt.figure(figsize=(20, 5))
plt.plot(months, sales, marker="o", linestyle="--", color="b", label="Sales")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales ($)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Bar Chart

# %%
plt.figure(figsize=(20, 5))
plt.bar(months, profit, color="g", label="Profit")
plt.title("Monthly Profit Trend")
plt.xlabel("Month")
plt.ylabel("Profit ($)")
plt.legend()
plt.grid(axis="y")
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
plt.figure(figsize=(20, 5))
plt.scatter(customers, sales, color="r", label="Customers vs Sales")
plt.title("Customers vs Sales Relationship")
plt.xlabel("Number of Customers")
plt.ylabel("Sales ($)")
plt.legend()
plt.grid(True)
plt.show()
